# %%
from cards import Deck
from matplotlib import pyplot as plt

# %%
num_times_to_shuffle = 4
num_trials = 500
num_cards = 52
positions = []
for i in range(num_trials):
    d = Deck(num_cards)
    d=d.shuffle(num_times_to_shuffle,num_cards//2)
    position = np.argsort(d.cards)
    positions.append(position)
positions = np.array(positions)

# %%
positions

# %%
plt.pcolor(positions)
plt.colorbar()

# %%
plt.pcolor(positions)
plt.colorbar()

# %%
d
