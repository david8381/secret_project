# %%
import deck
from matplotlib import pyplot as plt

D = deck.Deck(range(0, 52))
list_of_decks = []

# %%
list_of_decks = deck.create_list_of_decks(10000, 10, D)
array = deck.make_array(list_of_decks)

# %%
#print(array)

# %%
deck.display_array(array)

# %%
plt.hist(array.reshape(-1),bins=100)
# Out:
# (array([ 1.,  1.,  2.,  0.,  0.,  3.,  0.,  4.,  5.,  8.,  5.,  0.,  9.,  8.,  8., 12., 17., 16., 16., 23., 22., 20.,  0., 25., 35., 28., 40., 47., 46., 49., 51., 58., 73.,  0., 68., 74., 73., 63., 86., 80., 98., 85., 62., 76.,  0., 78., 74., 81., 82., 73., 63., 66., 80., 69., 64.,  0., 61., 47., 55., 39., 33., 35., 33., 27., 30., 19.,  0., 22., 16., 22., 18., 15., 19., 11., 14.,  7.,  5.,  0.,  4.,  9.,  4.,  5.,  7.,  3.,  1.,  2.,  0.,  2.,  0.,  3.,  3.,  3.,  0.,  0.,  1.,  1.,  0.,  0.,  0.,  1.]),
# ...

# %%
4/4**2
# Out:
# 0.25
